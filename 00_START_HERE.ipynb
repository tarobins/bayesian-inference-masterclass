# %% [markdown]
# # The Complete Bayesian Modeling Masterclass
# ### *From Classical Frequentist Estimation to Production Hamiltonian Monte Carlo*
#
# Welcome! This 5-part hands-on curriculum provides a complete, step-by-step masterclass in estimating population parameters, diagnosing convergence, and generating predictions in **R**.
#
# ---
#
# ## The Complete 5-Part Learning Progression
#
# | Sheet | Title | Core Question & Key Concept | Practical Tools |
# | :--- | :--- | :--- | :--- |
# | **[Sheet 1](01_frequentist_vs_grid_approximation.ipynb)** | **Foundations: Frequentist vs. Grid Approx** | Generative models, CI vs. Credible Intervals, 7 Deep Dives, Prior sensitivity & shrinkage | `t.test()`, `expand.grid()`, `dnorm()` |
# | **[Sheet 2](02_quadratic_laplace_approximation.ipynb)** | **Rapid Prototyping: Quadratic (Laplace) Approx** | Parabolic log-posteriors, inverting the Hessian matrix, Multivariate Normal draws | `optim(..., hessian=TRUE)`, `rethinking::quap()` |
# | **[Sheet 3](03_mcmc_mechanics_from_scratch.ipynb)** | **First Principles: MCMC Mechanics from Scratch** | Detailed balance, 3-step Metropolis rule, step-size tuning failure modes, autocorrelation decay | Pure Base R (`rnorm()`, `runif()`, `acf()`) |
# | **[Sheet 4](04_mcmc_production_diagnostics.ipynb)** | **Production Scale: Multi-Chain MCMC & Stan** | Multi-chain convergence, Gelman-Rubin $\hat{R}$, Effective Sample Size ($ESS$), HMC physics, PSIS-LOO model comparison | `coda`, `rethinking::ulam()`, `loo` |
# | **[Sheet 5 (Bonus)](05_bonus_real_world_bayesian_flakiness.ipynb)** | **Case Study: Real-World CI Test Flakiness** | Beta-Binomial conjugacy, online real-time updating in CI, automated quarantine rules, exponential memory decay | `dbeta()`, `pbeta()`, `qbeta()` |
#
# ---
#
# ## Quick Summary of Computational Paradigms
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │ 1. Grid Approximation  -->  Exact 2D lattice (1-3 parameters max)           │
# │ 2. Quadratic Approx    -->  Parabolic mode + Hessian (Instantaneous 0.001s) │
# │ 3. MCMC (Stan / HMC)   -->  Physics simulation / Random Walk (1000s params) │
# │ 4. Exact Conjugate     -->  Closed-form Beta-Binomial update (Real-time CI) │
# └─────────────────────────────────────────────────────────────────────────────┘
# ```
#
# **👉 Click [Sheet 1: 01_frequentist_vs_grid_approximation.ipynb](01_frequentist_vs_grid_approximation.ipynb) to begin!**
