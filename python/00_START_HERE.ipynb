# %% [markdown]
# # The Complete Bayesian Modeling Masterclass
# ### *From Classical Frequentist Estimation to Production Hamiltonian Monte Carlo*
#
# Welcome! This 6-part hands-on curriculum provides a complete, step-by-step masterclass in estimating population parameters, diagnosing convergence, and generating predictions in **Python (NumPy, SciPy, Matplotlib)**.
#
# ---
#
# ## The Complete 6-Part Learning Progression
#
# | Sheet | Title | Core Question & Key Concept | Practical Tools |
# | :--- | :--- | :--- | :--- |
# | **[Sheet 1](01_frequentist_vs_grid_approximation.ipynb)** | **Foundations: Frequentist vs. Grid Approx** | Generative models, CI vs. Credible Intervals, 7 Deep Dives, Prior sensitivity & shrinkage | `scipy.stats.ttest_1samp`, `np.meshgrid`, `scipy.stats.norm` |
# | **[Sheet 2](02_quadratic_laplace_approximation.ipynb)** | **Rapid Prototyping: Quadratic (Laplace) Approx** | Parabolic log-posteriors, inverting the Hessian matrix, Multivariate Normal draws | `scipy.optimize.minimize`, Laplace approximation |
# | **[Sheet 3](03_mcmc_mechanics_from_scratch.ipynb)** | **First Principles: MCMC Mechanics from Scratch** | Detailed balance, 3-step Metropolis rule, step-size tuning failure modes, autocorrelation decay | Pure Python (`numpy.random`, `scipy.stats`) |
# | **[Sheet 4](04_mcmc_production_diagnostics.ipynb)** | **Production Scale: Multi-Chain MCMC & Stan** | Multi-chain convergence, Gelman-Rubin $\hat{R}$, Effective Sample Size ($ESS$), HMC physics, PSIS-LOO model comparison | NumPy multi-chain, WAIC, PSIS-LOO |
# | **[Sheet 5 (Bonus)](05_bonus_real_world_bayesian_flakiness.ipynb)** | **Case Study: Real-World CI Test Flakiness** | Beta-Binomial conjugacy, online real-time updating in CI, automated quarantine rules, exponential memory decay | `scipy.stats.beta` (pdf, cdf, ppf, sf) |
# | **[Sheet 6](06_calibrating_bayesian_decay_and_memory.ipynb)** | **Calibration: Memory Decay ($\\gamma$)** | Half-life, steady-state $N_{\\text{eff}}$, SLA de-quarantine recovery, pre-quential backtesting | `scipy.stats.beta`, pre-quential log-likelihood |
#
# ---
#
# ## Quick Summary of Computational Paradigms
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │ 1. Grid Approximation  -->  Exact 2D lattice (1-3 parameters max)           │
# │ 2. Quadratic Approx    -->  Parabolic mode + Hessian (Instantaneous 0.001s) │
# │ 3. MCMC (Stan / HMC)   -->  Physics simulation / Random Walk (1000s params) │
# │ 4. Exact Conjugate     -->  Closed-form Beta-Binomial update (Real-time CI) │
# │ 5. Fading Memory Bayes  -->  Exponential discount factor γ (Half-life & ESS) │
# └─────────────────────────────────────────────────────────────────────────────┘
# ```
#
# **👉 Click [Sheet 1: 01_frequentist_vs_grid_approximation.ipynb](01_frequentist_vs_grid_approximation.ipynb) to begin!**
